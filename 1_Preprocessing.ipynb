# %%
import pandas as pd

# %%
df_train = pd.read_csv("data/train.csv")

# %%
display(df_train)
# Out:
#             id  is_appartment   area  added_time  bedrooms  new_building  \
# 0          tr0           True   88.0   141725167       2.0             0
# 1          tr1           True   55.0   132223171       1.0             0
# 2          tr2          False  333.0   119151262       4.0             0
# 3          tr3          False  517.0   137313038       5.0             0
# 4          tr4           True   99.0   137303955       3.0             0
# ...        ...            ...    ...         ...       ...           ...
# 27066  tr27066           True   81.0   141439187       2.0             0
# 27067  tr27067          False  165.0   141979060       3.0             0
# 27068  tr27068          False  157.0   142750425       4.0             0
# 27069  tr27069           True  113.0   141440600       2.0             1
# 27070  tr27070           True   39.0   121328619       1.0             0
#
#        postcode        lat       lon                    advertiser  \
# ...
